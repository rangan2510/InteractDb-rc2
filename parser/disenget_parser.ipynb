# %%
import pandas as pd
dis_map_df = pd.read_csv('../data/diseases/DisGeNET/disease_mappings.tsv', sep="\t")
dis_map_df
# Out:
#        diseaseId                                  name vocabulary     code  \
# 0       C0018923                       Hemangiosarcoma         DO  0001816
# 1       C0854893           Angiosarcoma non-metastatic         DO  0001816
# 2       C0033999                             Pterygium         DO  0002116
# 3       C0025517                    Metabolic Diseases         DO  0014667
# 4       C0155862               Streptococcal pneumonia         DO  0040084
# ...          ...                                   ...        ...      ...
# 242884  C0279628           Adenocarcinoma Of Esophagus       ORDO    99976
# 242885  C0279626  Squamous cell carcinoma of esophagus       ORDO    99977
# 242886  C0206702                        Klatskin Tumor       ORDO    99978
# 242887  C0007462                             Causalgia       ORDO    99994
# 242888  C0034931          Reflex Sympathetic Dystrophy       ORDO    99995
#
#                                   vocabularyName
# 0                                   angiosarcoma
# 1                                   angiosarcoma
# 2                                      pterygium
# 3                          disease of metabolism
# 4                        Streptococcus pneumonia
# ...                                          ...
# 242884           Adenocarcinoma of the esophagus
# 242885  Squamous cell carcinoma of the esophagus
# 242886                            Klatskin tumor
# 242887     Complex regional pain syndrome type 2
# 242888     Complex regional pain syndrome type 1
#
# [242889 rows x 5 columns]

# %%
dis_map_df.loc[dis_map_df['diseaseId'] == 'C0178238']
# Out:
#       diseaseId                                      name vocabulary  \
# 7178   C0178238  Intestinal infectious disease (disorder)         DO
# 39434  C0178238  Intestinal infectious disease (disorder)      ICD10
# 42222  C0178238  Intestinal infectious disease (disorder)    ICD10CM
# 52441  C0178238  Intestinal infectious disease (disorder)     ICD9CM
# 56916  C0178238  Intestinal infectious disease (disorder)      MONDO
#
#              code                            vocabularyName
# 7178          100             intestinal infectious disease
# 39434   A00-A09.9            Intestinal infectious diseases
# 42222     A00-A09  Intestinal infectious diseases (A00-A09)
# 52441  001-009.99            INTESTINAL INFECTIOUS DISEASES
# 56916     0000916             intestinal infectious disease

# %%
full_df = pd.read_csv('../data/diseases/DisGeNET/tables/diseaseFiltered.csv', sep="\t")
full_df
# Out:
#       diseaseId                                diseaseName     type  \
# 0      C0024286                   Lymphogranuloma Venereum  disease
# 1      C0001249                  Actinobacillus Infections  disease
# 2      C0339916    Viral upper respiratory tract infection    group
# 3      C1274320  Recurrent herpes simplex infection of eye  disease
# 4      C0001261                              Actinomycosis    group
# ...         ...                                        ...      ...
# 38319  C2700439                 MAJOR AFFECTIVE DISORDER 8  disease
# 38320  C0001306              Acute alcoholic liver disease  disease
# 38321  C0236816         Stress Disorders, Traumatic, Acute    group
# 38322  C0221745                        Depression suicidal  disease
# 38323  C0008074     Child Development Disorders, Pervasive    group
#
#       MeSH_tree_number         MeSH_heading
# 0                  C01           Infections
# 1                  C01           Infections
# 2                  C01           Infections
# 3                  C01           Infections
# 4                  C01           Infections
# ...                ...                  ...
# 38319              F03     Mental Disorders
# 38320              F03     Mental Disorders
# 38321              F03     Mental Disorders
# 38322              F03     Mental Disorders
# 38323              F03     Mental Disorders
#
# [38324 rows x 5 columns]

# %%
df = pd.merge(dis_map_df, full_df, on='diseaseId', how='inner')
len(df)
# Out:
# 413282

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        diseaseId                                     name vocabulary  \
# 0       C0018923                          Hemangiosarcoma         DO
# 1       C0018923                          Hemangiosarcoma        EFO
# 2       C0018923                          Hemangiosarcoma        HPO
# 3       C0018923                          Hemangiosarcoma      MONDO
# 4       C0018923                          Hemangiosarcoma        MSH
# ...          ...                                      ...        ...
# 413277  C0020681        Sleep-related respiratory failure       ORDO
# 413278  C0020681        Sleep-related respiratory failure       ORDO
# 413279  C1262019                          Uremic pruritus       ORDO
# 413280  C1262019                          Uremic pruritus       ORDO
# 413281  C1504369  Allergic disorder of respiratory system       ORDO
#
#               code                     vocabularyName  \
# 0          0001816                       angiosarcoma
# 1          0003968                       angiosarcoma
# 2       HP:0200058                       Angiosarcoma
# 3          0016982             angiosarcoma (disease)
# 4          D006394                    Hemangiosarcoma
# ...            ...                                ...
# 413277         661                    Ondine syndrome
# 413278         661                    Ondine syndrome
# 413279       94059                    Uremic pruritus
# 413280       94059                    Uremic pruritus
# 413281       98052  Rare allergic respiratory disease
#
#                                     diseaseName       type MeSH_tree_number  \
# 0                               Hemangiosarcoma    disease              C04
# 1                               Hemangiosarcoma    disease              C04
# 2                               Hemangiosarcoma    disease              C04
# 3                               Hemangiosarcoma    disease              C04
# 4                               Hemangiosarcoma    disease              C04
# ...                                         ...        ...              ...
# 413277        Sleep-related respiratory failure    disease              C23
# 413278        Sleep-related respiratory failure    disease              F03
# 413279                          Uremic pruritus  phenotype              C17
# 413280                          Uremic pruritus  phenotype              C23
# 413281  Allergic disorder of respiratory system    disease              C08
#
#                                           MeSH_heading
# 0                                            Neoplasms
# 1                                            Neoplasms
# 2                                            Neoplasms
# 3                                            Neoplasms
# 4                                            Neoplasms
# ...                                                ...
# 413277     Pathological Conditions, Signs and Symptoms
# 413278                                Mental Disorders
# 413279             Skin and Connective Tissue Diseases
# 413280     Pathological Conditions, Signs and Symptoms
# 413281                      Respiratory Tract Diseases
#
# [413282 rows x 9 columns]

# %%
df.to_excel("./temp/disease_icd.xlsx")
